# %%
# !pip install -U finance-datareader

# %%
pip install pykrx

# %%
import FinanceDataReader as fdr
from pykrx import stock

# %%
stocks = fdr.StockListing('KRX')
stocks
# Out:
#         Code        ISU_CD      Name Market   Dept   Close ChangeCode  \
# 0     005930  KR7005930003      삼성전자  KOSPI          66500          1
# 1     373220  KR7373220003  LG에너지솔루션  KOSPI         526000          2
# 2     000660  KR7000660001    SK하이닉스  KOSPI         115900          2
# 3     207940  KR7207940008  삼성바이오로직스  KOSPI         778000          1
# 4     005490  KR7005490008  POSCO홀딩스  KOSPI         552000          1
# ...      ...           ...       ...    ...    ...     ...        ...
# 2741  140660  KR7140660002       위월드  KONEX  일반기업부    1200          0
# 2742  245450  KR7245450002    씨앤에스링크  KONEX  일반기업부    1600          2
# 2743  288490  KR7288490006     나라소프트  KONEX  일반기업부      57          2
# 2744  322190  KR7322190000        베른  KONEX  일반기업부     170          3
# 2745  308700  KR7308700004       테크엔  KONEX  일반기업부     242          1
#
#       Changes  ChagesRatio    Open    High     Low   Volume        Amount  \
# ...

# %%
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2746 entries, 0 to 2745
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Code         2746 non-null   object
#  1   ISU_CD       2746 non-null   object
#  2   Name         2746 non-null   object
#  3   Market       2746 non-null   object
#  4   Dept         2746 non-null   object
#  5   Close        2746 non-null   object
#  6   ChangeCode   2746 non-null   object
#  7   Changes      2746 non-null   int64
#  8   ChagesRatio  2746 non-null   float64
#  9   Open         2746 non-null   int64
#  10  High         2746 non-null   int64
#  11  Low          2746 non-null   int64
#  12  Volume       2746 non-null   int64
#  13  Amount       2746 non-null   int64
#  14  Marcap       2746 non-null   int64
#  15  Stocks       2746 non-null   int64
#  16  MarketId     2746 non-null   object
# dtypes: float64(1), int64(8), object(8)
# memory usage: 364.8+ KB

# %%
df = stocks

# %%
#에너지
kospi_energy = ['017940', '010950', '010955', '034730', '03473K', '018670', '096770', '096775', '014530', '128820', '002420', '091090', '126720',
            '011930', '112610', '100840', '005090', '006120', '006125', '267250', '093230', '078930', '0789035', '052690', '152550', '130660',
            '322000']
df2 = df.loc[df['Code'].isin(kospi_energy)]
df2
# Out:
#         Code        ISU_CD        Name Market Dept   Close ChangeCode  \
# 20    096770  KR7096770003     SK이노베이션  KOSPI       176000          1
# 36    034730  KR7034730002          SK  KOSPI       140200          1
# 46    010950  KR7010950004       S-Oil  KOSPI        73600          1
# 77    267250  KR7267250009        HD현대  KOSPI        59300          1
# 91    078930  KR7078930005          GS  KOSPI        38250          1
# 112   112610  KR7112610001       씨에스윈드  KOSPI        65700          1
# 120   052690  KR7052690005        한전기술  KOSPI        65900          1
# 235   018670  KR7018670000        SK가스  KOSPI       122500          2
# 328   006120  KR7006120000     SK디스커버리  KOSPI        39600          2
# 400   011930  KR7011930005       신성이엔지  KOSPI         2645          1
# 525   017940  KR7017940008          E1  KOSPI        56200          2
# 549   005090  KR7005090006      SGC에너지  KOSPI        25250          2
# ...

# %%
#소재
kospi_material = ['004840', '001940', '025000', '092230', '051910', '051915', '002360', '011790', '283130', '28413K', '002100', '012320',
           '012610', '010130', '002240', '007690', '083420', '008870', '001370', '011780', '011785', '004540', '008350',
           '008355', '025860', '009190', '014160', '012800', '006650', '084010', '003830', '069460', '001230', '023450',
           '007590', '102260', '001520', '001525', '001527', '008970', '014820', '014825', '163560', '004890', '002690',
           '024090', '155660', '069730', '000210', '000215', '115390', '004000', '0011170', '001080', '009200', '009580',
           '008420', '002840', '268280', '107590']
df3 = df.loc[df['Code'].isin(kospi_material)]
df3
# Out:
#         Code        ISU_CD      Name Market Dept   Close ChangeCode  Changes  \
#
code        ISU_CD      Name Market Dept   Close ChangeCode  Changes  \
# 18    028260  KR7028260008      삼성물산  KOSPI       102500          1      100
# 22    047050  KR7047050000  포스코인터내셔널  KOSPI        81100          2     -400
# 24    003550  KR7003550001        LG  KOSPI        80700          1     1000
# 31    329180  KR7329180004   HD현대중공업  KOSPI       122200          1     1200
# 37    034020  KR7034020008   두산에너빌리티  KOSPI        16000          2      -20
# ...      ...           ...       ...    ...  ...     ...        ...      ...
# 2725  000325  KR7000321000    노루홀딩스우  KOSPI        19040          1       20
# 2727  002995  KR7002991008     금호건설우  KOSPI        14900          2     -550
# 2732  002785  KR7002781003    진흥기업우B  KOSPI         4160          2      -35
# 2733  014915  KR7014911002     성문전자우  KOSPI         5780          1      130
# 2739  002787  KR7002782001   진흥기업2우B  KOSPI        10970          2      -50
#
# ...

# %%
kospi_economic_m = ['001460', '001465', '089470', '093050', '066570', '066575', '000680', '035250', '011420', '009450',
                    '000050', '012200', '012205', '037710', '005320', '012200', '012205', '037710', '005320',
                    '114090', '214330', '073240', '000270', '005720', '005725', '002350', '002355', '145210',
                    '019680', '019685', '006370', '009320', '000430', '024890', '002880', '000300', '001070',
                    '016090', '004830', '004835', '024900', '082690', '092780', '018500', '016940', '001530',
                    '092200', '007340', '210540', '032350', '089860', '023530', '004990', '00499K', '071840',
                    '009900', '009680', '003610', '035150', '005030', '002070', '100220', '027410', '282330',
                    '006660', '068290', '002170', '023000', '002450', '041650', '075180', '007860', '200880',
                    '011300', '004490', '021820', '067830', '033530', '208170', '134790', '005390', '004170',
                    '031430', '005800', '009270', '002700', '102280', '003620', '015540', '403550', '079160',
                    '008700', '012170', '122900', '003560', '011090', '034120', '064960', '003570', '036530',
                    '005850', '010580', '123700', '025530', '001380', '004060', '068400', '204320', '003580',
                    '060980', '383220', '007700', '900140', '037560', '111770', '009970', '012280', '037270',
                    '070960', '017370', '095720', '008600', '047400', '011330', '002920', '214320', '139480',
                    '084680', '014990', '101140', '023800', '023810', '003200', '008500', '271940', '000950',
                    '194370']
df5 = df.loc[df['Symbol'].isin(kospi_economic_m)]
df5
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Symbol'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
start_date = '2010-01-01'
end_date = '2022-06-01'

df_sk = fdr.DataReader('034730', start=start_date, end=end_date)
df_sk
# Out:
#               Open    High     Low   Close   Volume    Change
# Date
# 2010-01-04   45300   47600   44700   47250   417372  0.054688
# 2010-01-05   48000   49800   47350   49050   814860  0.038095
# 2010-01-06   49250   51300   48600   50000   716281  0.019368
# 2010-01-07   50000   52500   49700   52100   718497  0.042000
# 2010-01-08   52400   58500   51000   55000  1100618  0.055662
# ...            ...     ...     ...     ...      ...       ...
# 2022-05-25  235000  238000  235000  236500   177441  0.015021
# 2022-05-26  236500  238500  234500  236000   158214 -0.002114
# 2022-05-27  239000  240500  237000  238000   117097  0.008475
# 2022-05-30  240500  243000  240000  243000   110215  0.021008
# 2022-05-31  243500  248500  241500  248000   657683  0.020576
#
# [3063 rows x 6 columns]

# %%
#촛대그래프

# %%
pip install plotly

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go

df = df_sk.reset_index()

fig = go.Figure(data=[go.Candlestick(x=df['Date'],
                                    open=df['Open'],
                                    high=df['High'],
                                    low=df['Low'],
                                    close=df['Close'])])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#촛대차트(금융파이썬쿡북)

# %%
pip install chart_studio

# %%
import pandas as pd
import FinanceDataReader as fdr
from pykrx import stock

# %%
start_date = '2010-01-01'
end_date = '2022-06-01'

df_sk = fdr.DataReader('034730', start=start_date, end=end_date)
df_sk

# %%
import cufflinks as cf
from plotly.offline import iplot, init_notebook_mode

init_notebook_mode()

# %%
qf = cf.QuantFig(df_sk, title = "sk's stock price", legend = 'top', name = 'sk')

# %%
qf.add_volume()
qf.add_sma(periods=20, column='Close', color='red')
qf.add_ema(periods=20, color='green')

# %%
qf.iplot()

# %% [markdown]
# Authentication credentials were not provided ( 인증 자격 증명이 제공되지 않았습니다 ? )

# %%
pip install backtrader

# %%
from datetime import datetime
import backtrader as bt

# %%
class SmaSignal(bt.Signal):
    params = (('period', 20), )

    def __init__(self):
        self.lines.signal = self.data - bt.ind.SMA(period=self.p.period)

# %%
start_date = '2010-01-01'
end_date = '2022-06-01'

data = bt.fdr.DataReader('034730', start=start_date, end=end_date)

# %%
cerebro = bt.Cerebro(stdstats = False)

cerebro.adddata(data)
cerebro.broker.setcash(1000.0)
cerebro.add_signal(bt.SIGNAL_LONG, SmaSignal)
cerebro.addobserver(bt.observers.BuySell)
cerebro.addobserver(bt.observers.Value)

# %%
print(f'Starting Portfolio Value: {cerebro.broker.getvalue():.2f}')
cerebro.run()
print(f'Final Portfolio Value: {cerebro.broker.getvalue():.2f}')

# %%
pip install yfinance

# %%
from datetime import datetime
import backtrader as bt

# Create a subclass of Strategy to define the indicators and logic

class SmaCross(bt.Strategy):
    # list of parameters which are configurable for the strategy
    params = dict(
        pfast=10,  # period for the fast moving average
        pslow=30   # period for the slow moving average
    )

    def __init__(self):
        sma1 = bt.ind.SMA(period=self.p.pfast)  # fast moving average
        sma2 = bt.ind.SMA(period=self.p.pslow)  # slow moving average
        self.crossover = bt.ind.CrossOver(sma1, sma2)  # crossover signal

    def next(self):
        if not self.position:  # not in the market
            if self.crossover > 0:  # if fast crosses slow to the upside
                self.buy()  # enter long

        elif self.crossover < 0:  # in the market & cross to the downside
            self.close()  # close long position


cerebro = bt.Cerebro()  # create a "Cerebro" engine instance

# Create a data feed
data = bt.feeds.YahooFinanceData(dataname='MSFT',
                                 fromdate=datetime(2011, 1, 1),
                                 todate=datetime(2012, 12, 31),
                                 progress=False)

cerebro.adddata(data)  # Add the data feed

cerebro.addstrategy(SmaCross)  # Add the trading strategy
cerebro.run()  # run it all
cerebro.plot()  # and plot it with a single command

# %%
import pandas as pd
import yfinance as yf

# 데이터 다운로드
df_yahoo = yf.download('AAPL',
                       start='2000-01-01',
                       end='2010-12-31',
                       progress=False)

# 데이터 출력
print(f'Downloaded {df_yahoo.shape[0]} rows of data.')
df_yahoo.head()

# %%
pip install yfinance
